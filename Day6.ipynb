# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekauti21/greyatomcodes/blob/master/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ls
# Out:
# sample_data/  WorldHappiness2018_Data.csv

# %%
df = pd.read_csv('WorldHappiness2018_Data.csv' )

# %%
df
# Out:
#      Rank                   Country  ...  Perceptions_Of_Corruption  Residual
# 0       1                   Finland  ...                      0.393     2.988
# 1       2                    Norway  ...                      0.340     2.723
# 2       3                   Denmark  ...                      0.408     2.779
# 3       4                   Iceland  ...                      0.138     2.564
# 4       5               Switzerland  ...                      0.357     2.675
# ..    ...                       ...  ...                        ...       ...
# 151   152                     Yemen  ...                      0.064     1.170
# 152   153                  Tanzania  ...                      0.097     0.725
# 153   154               South Sudan  ...                      0.106     1.796
# 154   155  Central African Republic  ...                      0.038     2.526
# 155   156                   Burundi  ...                      0.076     1.828
#
# [156 rows x 10 columns]

# %%
print(df.head())
# Out:
#    Rank      Country  Score  ...  Generosity  Perceptions_Of_Corruption  Residual
# 0     1      Finland  7.632  ...       0.192                      0.393     2.988
# 1     2       Norway  7.594  ...       0.286                      0.340     2.723
# 2     3      Denmark  7.555  ...       0.284                      0.408     2.779
# 3     4      Iceland  7.495  ...       0.353                      0.138     2.564
# 4     5  Switzerland  7.487  ...       0.256                      0.357     2.675
#
# [5 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
x1=df['Score']

# %%
y1=df['Rank']

# %%
plt.plot(x1,y1)

# %%
gdp=df['GDP_Per_Capita']

# %%
lifeexpentency=df['Healthy_Life_Expectancy']

# %%
plt.plot(y1,lifeexpentency)

# %%
plt.show()

# %%
plt.plot(y1,gdp,color="green")
plt.plot(y1,lifeexpentency,color="red")
plt.title("y1")
plt.xlabel("Rank")
plt.legend(['one','two'])
plt.show()

# %%
plt.hist(x1)
plt.legend(['one','two'])
plt.show()

# %%
df["Score"].apply(int)
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 151    3
# 152    3
# 153    3
# 154    3
# 155    2
# Name: Score, Length: 156, dtype: int64

# %%
df["Score"].apply(int).value_counts()
# Out:
# 5    50
# 4    41
# 6    34
# 3    17
# 7    13
# 2     1
# Name: Score, dtype: int64

# %%
score_int=df["Score"].apply(int)
count_score=score_int.value_counts()

# %%
plt.bar(count_score.index,count_score)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.hist(df['Score'],edgecolor='red',linewidth=9,color='black')
# Out:
# (array([ 5., 11., 12., 26., 18., 22., 25., 16., 10., 11.]),
#  array([2.905 , 3.3777, 3.8504, 4.3231, 4.7958, 5.2685, 5.7412, 6.2139,
#         6.6866, 7.1593, 7.632 ]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(gdp,x1)

# %%
dfplt.boxplot()
plt.boxplot(gdp)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f08e0e63e80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f08e0e7aba8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f08e0dd55c0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f08e0dd5278>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f08e0e7a518>,
#   <matplotlib.lines.Line2D at 0x7f08e0e7a860>]}

# %%
import numpy as np

# %%
a=np.random.randint(1,10)
a
# Out:
# 5

# %%
import seaborn as sns
import numpy as np

# %%
a=np.random.randn(10,12)
a
# Out:
# array([[-0.69684617, -0.58739472,  0.46344965, -0.56228394, -1.00747642,
#          0.86624967, -0.11110933,  0.27110302,  0.97185702,  0.31197144,
#          0.33950532,  0.64784342],
#        [-0.30550163,  0.3141525 , -0.99804978,  1.45619853,  0.14775   ,
#         -1.22734811, -0.29573092,  0.52689495, -1.49349787,  1.69852521,
#         -0.69716358, -0.0642493 ],
#        [-0.57970881,  0.22043005, -1.06336257, -0.85609015, -1.07012229,
#          0.39632742, -0.09238847, -0.90337674,  1.03776456,  1.30066562,
#          0.08860396,  2.32780444],
#        [ 1.23888524, -1.30469613, -0.67288403,  1.06864338, -0.71519751,
#         -0.51425681,  0.01875749,  0.27481944,  0.3632301 ,  0.13012402,
#         -0.4265491 ,  2.26247167],
#        [-1.8108857 ,  0.21927045,  1.958053  , -1.25183851,  0.45689535,
#          1.90970976, -0.22039895, -1.02808908, -1.14240612,  1.85084828,
#         -0.38585767, -0.13865858],
# ...

# %%
sns.heatmap(a,linewidth=0.5)

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
sns.heatmap(df[['Score','GDP_Per_Capita','Healthy_Life_Expectancy']])

# %%
z=df[['Score','Freedom_To_Make_Life_Choices','Perceptions_Of_Corruption','GDP_Per_Capita']]

# %%
sns.heatmap(z.corr())

# %%
sns.violinplot(df['Score'])

# %%
sns.violinplot(df[['Score','Freedom_To_Make_Life_Choices','Perceptions_Of_Corruption']])

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(x=tips['total_bill'])

# %%
sns.violinplot(x="day",y="total_bill",data=tips)

# %%
sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips,palette="muted")

# %%
print(df['Country'].unique())
# Out:
# ['Finland' 'Norway' 'Denmark' 'Iceland' 'Switzerland' 'Netherlands'
#  'Canada' 'New Zealand' 'Sweden' 'Australia' 'Israel' 'Austria'
#  'Costa Rica' 'Ireland' 'Germany' 'Belgium' 'Luxembourg' 'United States'
#  'United Kingdom' 'United Arab Emirates' 'Czech Republic' 'Malta' 'France'
#  'Mexico' 'Chile' 'Taiwan' 'Panama' 'Brazil' 'Argentina' 'Guatemala'
#  'Uruguay' 'Qatar' 'Saudi Arabia' 'Singapore' 'Malaysia' 'Spain'
#  'Colombia' 'Trinidad & Tobago' 'Slovakia' 'El Salvador' 'Nicaragua'
#  'Poland' 'Bahrain' 'Uzbekistan' 'Kuwait' 'Thailand' 'Italy' 'Ecuador'
#  'Belize' 'Lithuania' 'Slovenia' 'Romania' 'Latvia' 'Japan' 'Mauritius'
#  'Jamaica' 'South Korea' 'Northern Cyprus' 'Russia' 'Kazakhstan' 'Cyprus'
#  'Bolivia' 'Estonia' 'Paraguay' 'Peru' 'Kosovo' 'Moldova' 'Turkmenistan'
#  'Hungary' 'Libya' 'Philippines' 'Honduras' 'Belarus' 'Turkey' 'Pakistan'
#  'Hong Kong' 'Portugal' 'Serbia' 'Greece' 'Tajikistan' 'Montenegro'
# ...

# %%
sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips,palette="muted",split=True)

# %%
sns.violinplot(x="time", y="tip", data=tips,order=["Dinner", "Lunch"])

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(2, 1, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(2, 1, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(2, 1, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(2, 2, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fig, axs=plt.subplots(2,2)
axs[0,0].plot(x1,y1,'tab:orange')
axs[0,0].set_title('1st')

axs[0,1].plot(x1,y1,'tab:red')
axs[0,1].set_title('2nd')

axs[1,0].plot(x1,y1,'tab:green')
axs[1,0].set_title('3rd')

axs[1,1].plot(x1,y1,'tab:blue')
axs[1,1].set_title('4th')
# Out:
# Text(0.5, 1.0, '4th')

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(1, 2, 1)
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(1, 2, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
for i in range(1,9):
  plt.subplot(4,2,i)
  plt.plot(x1,y1)
  i=i+1
plt.tight_layout()
plt.show()
