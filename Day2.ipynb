# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishekauti21/greyatomcodes/blob/master/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="new york"

# %%
print(a)
# Out:
# new york

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
print(len(a))
# Out:
# 8

# %%
b="india"

# %%
print(a+b)
# Out:
# new yorkindia

# %%
c=a+b

# %%
print(c)
# Out:
# new yorkindia

# %%
print(c:0)
# Out:
#   File "<ipython-input-9-ad8fffd88b91>", line 1
#     print(c:0)
#            ^
# SyntaxError: invalid syntax

# %%
print(c[0])
# Out:
# n

# %%
t=c.upper()

# %%
print(t)
# Out:
# NEW YORKINDIA

# %%
list=("abhi",22,25,26,"delhi",58,65,92,32,69)

# %%
print(list)
# Out:
# ('abhi', 22, 25, 26, 'delhi', 58, 65, 92, 32, 69)

# %%
"a"in list
# Out:
# False

# %%
"a" not in list
# Out:
# True

# %%
id(11)
# Out:
# 10914816

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4a363df3-9bbc-4614-9133-35a1018dafec" name="files[]" multiple disabled />
#      <output id="result-4a363df3-9bbc-4614-9133-35a1018dafec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ipl_match.yaml to ipl_match.yaml
# ...

# %%
# !ls
# Out:
# ipl_match.yaml  sample_data/

# %%
import yaml

# %%
with open('./data/ipl_match.yaml')as f:
  data=yaml.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-8b3ad910d3d3> in <module>()
# ----> 1 with open('./data/ipl_match.yaml')as f:
#       2   data =yaml.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/ipl_match.yaml'

# %%
# !ls
# Out:
# ipl_match.yaml	sample_data

# %%
with open('ipl_match.yaml')as f:
  data=yaml.load(f)

# %%
data
# Out:
# {'info': {'city': 'Bangalore',
#   'competition': 'IPL',
#   'dates': [datetime.date(2008, 4, 18)],
#   'gender': 'male',
#   'match_type': 'T20',
#   'outcome': {'by': {'runs': 140}, 'winner': 'Kolkata Knight Riders'},
#   'overs': 20,
#   'player_of_match': ['BB McCullum'],
#   'teams': ['Royal Challengers Bangalore', 'Kolkata Knight Riders'],
#   'toss': {'decision': 'field', 'winner': 'Royal Challengers Bangalore'},
#   'umpires': ['Asad Rauf', 'RE Koertzen'],
#   'venue': 'M Chinnaswamy Stadium'},
#  'innings': [{'1st innings': {'deliveries': [{0.1: {'batsman': 'SC Ganguly',
#        'bowler': 'P Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'BB McCullum',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {0.2: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
#        'non_striker': 'SC Ganguly',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.3: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
# ...

# %%
f=open("ipl_match.yaml")

# %%
data
# Out:
# {'info': {'city': 'Bangalore',
#   'competition': 'IPL',
#   'dates': [datetime.date(2008, 4, 18)],
#   'gender': 'male',
#   'match_type': 'T20',
#   'outcome': {'by': {'runs': 140}, 'winner': 'Kolkata Knight Riders'},
#   'overs': 20,
#   'player_of_match': ['BB McCullum'],
#   'teams': ['Royal Challengers Bangalore', 'Kolkata Knight Riders'],
#   'toss': {'decision': 'field', 'winner': 'Royal Challengers Bangalore'},
#   'umpires': ['Asad Rauf', 'RE Koertzen'],
#   'venue': 'M Chinnaswamy Stadium'},
#  'innings': [{'1st innings': {'deliveries': [{0.1: {'batsman': 'SC Ganguly',
#        'bowler': 'P Kumar',
#        'extras': {'legbyes': 1},
#        'non_striker': 'BB McCullum',
#        'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#      {0.2: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
#        'non_striker': 'SC Ganguly',
#        'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#      {0.3: {'batsman': 'BB McCullum',
#        'bowler': 'P Kumar',
# ...

# %%
f.read()
# Out:
# '---\nmeta:\n  data_version: 0.9\n  created: 2011-05-06\n  revision: 2\ninfo:\n  city: Bangalore\n  competition: IPL\n  dates:\n    - 2008-04-18\n  gender: male\n  match_type: T20\n  outcome:\n    by:\n      runs: 140\n    winner: Kolkata Knight Riders\n  overs: 20\n  player_of_match:\n    - BB McCullum\n  teams:\n    - Royal Challengers Bangalore\n    - Kolkata Knight Riders\n  toss:\n    decision: field\n    winner: Royal Challengers Bangalore\n  umpires:\n    - Asad Rauf\n    - RE Koertzen\n  venue: M Chinnaswamy Stadium\ninnings:\n  - 1st innings:\n      team: Kolkata Knight Riders\n      deliveries:\n        - 0.1:\n            batsman: SC Ganguly\n            bowler: P Kumar\n            extras:\n              legbyes: 1\n            non_striker: BB McCullum\n            runs:\n              batsman: 0\n              extras: 1\n              total: 1\n        - 0.2:\n            batsman: BB McCullum\n            bowler: P Kumar\n            non_striker: SC Ganguly\n            
# ...

# %%
f=open("ipl_match.yaml")

# %%
data1=yaml.load(f)

# %%
data1.keys()
h=data1["meta"].keys()

# %%
data1[h["data_version"]].keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-0112039b6c2f> in <module>()
# ----> 1 data1[h["data_version"]].keys()
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
type (data1)
# Out:
# dict

# %%
data1['info']['city']
# Out:
# 'Bangalore'

# %%
w=data1.keys()

# %%
w
# Out:
# dict_keys(['meta', 'info', 'innings'])

# %%
w
# Out:
# dict_keys(['meta', 'info', 'innings'])

# %%
data1['info']['city']
# Out:
# 'Bangalore'

# %%
data1['info']['venue'].keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-7aaba91bced1> in <module>()
# ----> 1 data1['info']['venue'].keys()
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
o=data1['info']['teams']

# %%
o
# Out:
# ['Royal Challengers Bangalore', 'Kolkata Knight Riders']

# %%
type(o)
# Out:
# list

# %%
o[0]
# Out:
# 'Royal Challengers Bangalore'

# %%
len(o)
# Out:
# 2

# %%
data1['innings']
# Out:
# [{'1st innings': {'deliveries': [{0.1: {'batsman': 'SC Ganguly',
#       'bowler': 'P Kumar',
#       'extras': {'legbyes': 1},
#       'non_striker': 'BB McCullum',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {0.2: {'batsman': 'BB McCullum',
#       'bowler': 'P Kumar',
#       'non_striker': 'SC Ganguly',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.3: {'batsman': 'BB McCullum',
#       'bowler': 'P Kumar',
#       'extras': {'wides': 1},
#       'non_striker': 'SC Ganguly',
#       'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#     {0.4: {'batsman': 'BB McCullum',
#       'bowler': 'P Kumar',
#       'non_striker': 'SC Ganguly',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.5: {'batsman': 'BB McCullum',
#       'bowler': 'P Kumar',
#       'non_striker': 'SC Ganguly',
#       'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#     {0.6: {'batsman': 'BB McCullum',
#       'bowler': 'P Kumar',
# ...

# %%
type(data1['innings'])
# Out:
# list

# %%
data1['innings'][0]
# Out:
# {'1st innings': {'deliveries': [{0.1: {'batsman': 'SC Ganguly',
#      'bowler': 'P Kumar',
#      'extras': {'legbyes': 1},
#      'non_striker': 'BB McCullum',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {0.2: {'batsman': 'BB McCullum',
#      'bowler': 'P Kumar',
#      'non_striker': 'SC Ganguly',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.3: {'batsman': 'BB McCullum',
#      'bowler': 'P Kumar',
#      'extras': {'wides': 1},
#      'non_striker': 'SC Ganguly',
#      'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#    {0.4: {'batsman': 'BB McCullum',
#      'bowler': 'P Kumar',
#      'non_striker': 'SC Ganguly',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.5: {'batsman': 'BB McCullum',
#      'bowler': 'P Kumar',
#      'non_striker': 'SC Ganguly',
#      'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#    {0.6: {'batsman': 'BB McCullum',
#      'bowler': 'P Kumar',
#      'non_striker': 'SC Ganguly',
# ...

# %%
data1['info']['toss']['winner'],data1['info']['toss']['decision']
# Out:
# ('Royal Challengers Bangalore', 'field')

# %%
data1['innings'][0]['1st innings']['deliveries'][0][0.1]['bowler']
# Out:
# 'P Kumar'

# %%
data1['innings'][0]['1st innings']['deliveries'][0][0.1]['batsman']
# Out:
# 'SC Ganguly'

# %%
print(data1['innings'][0]['1st innings']['deliveries'][0][0.1]['bowler'])
print(data1['innings'][0]['1st innings']['deliveries'][0][0.1]['batsman'])
# Out:
# P Kumar
# SC Ganguly

# %%
print(data1['info']['outcome']['by']['runs'],
data1['info']['outcome']['winner'])
# Out:
# 140 Kolkata Knight Riders

# %%
data1['info'].keys()
# Out:
# dict_keys(['city', 'competition', 'dates', 'gender', 'match_type', 'outcome', 'overs', 'player_of_match', 'teams', 'toss', 'umpires', 'venue'])

# %%
d1={"a":11,"b":22,"c":33,"d":55}

# %%
k=list(d1.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-ca37bda4d4c3> in <module>()
# ----> 1 k=list(d1.keys())
#
# TypeError: 'tuple' object is not callable

# %%
v=list(d1.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-494056f07d51> in <module>()
# ----> 1 v=list(dict.values())
#
# TypeError: 'tuple' object is not callable

# %%
dict[v(3)]=[k(3)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-a99136df1a68> in <module>()
# ----> 1 dict[v(3)]=[k(3)]
#
# TypeError: 'dict_keys' object is not callable

# %%
d1={"a":1,"b":2,"c":3,"d":44}

# %%
k=list(d1.keys())

# %%
v=list(d1.values())

# %%
k
# Out:
# ['a', 'b', 'c', 'd']

# %%
v
# Out:
# [1, 2, 3, 44]

# %%
d2={}
for i in range(len(d1)):
  d2[v[i]]=k[i]

# %%
print(d2)
# Out:
# {1: 'a', 2: 'b', 3: 'c', 44: 'd'}

# %%
p={'python':110,'java':111,'c':112}

# %%
k1=list(p.keys())
v1=list(p.values())

# %%
k1[v1.index(112)]
# Out:
# 'c'
